# %%
from DNA import DNA
from Graficador import *
from Seleccion import Seleccion
import pandas as pd
from Cromosoma import Cromosoma

# %%
DATOS_EN_TABLA = '../TablaCapitales.xlsx' 
RUTA =  DATOS_EN_TABLA
FILAS_TABLA = 24 
lista_provincias_visitadas = []
cantidad_km = 0 

df = pd.read_excel(DATOS_EN_TABLA)

def devolver_informacion_tabla_crudo():
    df = pd.read_excel(RUTA)
    tabla = df.values 
 
    return tabla

# %%
def procesar_informacion_tabla(tabla: pd.DataFrame):
    lista_provincias = list(tabla[:,0])
    
    return [lista_provincias, tabla]

lista_provincias,tabla = procesar_informacion_tabla(devolver_informacion_tabla_crudo())

# %%
 

def get_distance(city1: str, city2: str) -> float: 
    distancia = tabla[city1][city2+1]
    if type(distancia) == float:
        return distancia

# %% [markdown]
# Generando un marco de datos

# %%
def ciclo(poblacion,fObjetivo,fFitness,numero_ciclo):
    DNA1 =  DNA(poblacion)
    elites = []
    res_objetivo = DNA1.calcular_objetivo(fObjetivo)
    res_fitness = DNA1.calcular_fitness(fFitness)
 
    elites = Seleccion.elitismo(DNA1.poblacion,2) # NO ES UN METODO DE SELCCION
    cantidad = 10-len(elites)
    
    cromosomas_padres = Seleccion.torneo(DNA1.poblacion,cantidad)
    # cromosomas_padres = Seleccion.ruleta(DNA1.poblacion,vueltas=cantidad)
    cromosomas_hijos = DNA.cruzar_poblacion_numeros(cromosomas_padres)    

    if len(cromosomas_hijos)>0:
        nueva_poblacion = cromosomas_hijos + elites

    # print(len(nueva_poblacion))
    return nueva_poblacion

# %%
ciclos = 200
cantidad_cromosomas = 50
funcion_objetivo = lambda x,y: get_distance(x,y)       #  esto tiene que devolver la distancia, no?
fitness = lambda x: 1/x # distancia total?
Cromosoma.setProbMutacion(0.05)
Cromosoma.setProbCrossover(0.75)
poblacion = DNA.generar_poblacion_numeros(cantidad_cromosomas)
# poblaciones = []
mejor_cromosoma = [0,None]
# poblaciones.append(poblacion)

for i in range(ciclos):
    nueva_poblacion = ciclo(poblacion,funcion_objetivo,fitness,i)
    # for cromosoma in nueva_poblacion:
    poblacion = nueva_poblacion
    if i == ciclos-1:
        for cromosoma in poblacion:
            if cromosoma.objetivo > mejor_cromosoma[0]:
                mejor_cromosoma[0] = cromosoma.objetivo
                mejor_cromosoma[1] = cromosoma
            

    
    # poblaciones.append(poblacion)    
    print(f'-----------{i+1}------------')

# hacerGrafico(estadisticas, ciclos)
# display(hacerTabla(estadisticas, ciclos))
ultimo_cromosoma = mejor_cromosoma[1]

print(f'Ultimo cromosoma: {ultimo_cromosoma}')
for ciudad in range(0,len(ultimo_cromosoma.genes)-2):
    ciudad1 = ultimo_cromosoma.genes[ciudad]
    ciudad2 = ultimo_cromosoma.genes[ciudad+1]
    distancia = get_distance(ciudad1,ciudad2)
    print(f'{get_distance(ciudad1,ciudad2)}    | [{ciudad1}][{ciudad2}]  {lista_provincias[ciudad1]} -> {lista_provincias[ciudad2]} ')

print(f'KM(Totales = objt): {ultimo_cromosoma.objetivo} km | fitness = {ultimo_cromosoma.fitness}')

 

# [17, 22, 14, 12, 5, 15, 7, 6, 13, 3, 2, 9, 4, 8, 20, 18, 11, 16, 21, 1, 23, 19, 10]
# Out:
# self.poblacion 50
# -----------1------------
# self.poblacion 10
# -----------2------------
# self.poblacion 10
# -----------3------------
# self.poblacion 10
# -----------4------------
# self.poblacion 10
# -----------5------------
# self.poblacion 10
# -----------6------------
# self.poblacion 10
# -----------7------------
# self.poblacion 10
# -----------8------------
# self.poblacion 10
# -----------9------------
# self.poblacion 10
# -----------10------------
# self.poblacion 10
# -----------11------------
# self.poblacion 10
# -----------12------------
# self.poblacion 10
# -----------13------------
# self.poblacion 10
# -----------14------------
# self.poblacion 10
# -----------15------------
# self.poblacion 10
# -----------16------------
# self.poblacion 10
# -----------17------------
# self.poblacion 10
# -----------18------------
# self.poblacion 10
# -----------19------------
# self.poblacion 10
# -----------20------------
# self.poblacion 10
# -----------21------------
# self.poblacion 10
# -----------22------------
# self.poblacion 10
# -----------23------------
# self.poblacion 10
# -----------24------------
# self.poblacion 10
# -----------25------------
# self.poblacion 10
# -----------26------------
# self.poblacion 10
# -----------27------------
# self.poblacion 10
# -----------28------------
# self.poblacion 10
# -----------29------------
# self.poblacion 10
# -----------30------------
# self.poblacion 10
# -----------31------------
# self.poblacion 10
# -----------32------------
# self.poblacion 10
# -----------33------------
# self.poblacion 10
# -----------34------------
# self.poblacion 10
# -----------35------------
# self.poblacion 10
# -----------36------------
# self.poblacion 10
# -----------37------------
# self.poblacion 10
# -----------38------------
# self.poblacion 10
# -----------39------------
# self.poblacion 10
# -----------40------------
# self.poblacion 10
# -----------41------------
# self.poblacion 10
# -----------42------------
# self.poblacion 10
# -----------43------------
# self.poblacion 10
# -----------44------------
# self.poblacion 10
# -----------45------------
# self.poblacion 10
# -----------46------------
# self.poblacion 10
# -----------47------------
# self.poblacion 10
# -----------48------------
# self.poblacion 10
# -----------49------------
# self.poblacion 10
# -----------50------------
# self.poblacion 10
# -----------51------------
# self.poblacion 10
# -----------52------------
# self.poblacion 10
# -----------53------------
# self.poblacion 10
# -----------54------------
# self.poblacion 10
# -----------55------------
# self.poblacion 10
# -----------56------------
# self.poblacion 10
# -----------57------------
# self.poblacion 10
# -----------58------------
# self.poblacion 10
# -----------59------------
# self.poblacion 10
# -----------60------------
# self.poblacion 10
# -----------61------------
# self.poblacion 10
# -----------62------------
# self.poblacion 10
# -----------63------------
# self.poblacion 10
# -----------64------------
# self.poblacion 10
# -----------65------------
# self.poblacion 10
# -----------66------------
# self.poblacion 10
# -----------67------------
# self.poblacion 10
# -----------68------------
# self.poblacion 10
# -----------69------------
# self.poblacion 10
# -----------70------------
# self.poblacion 10
# -----------71------------
# self.poblacion 10
# -----------72------------
# self.poblacion 10
# -----------73------------
# self.poblacion 10
# -----------74------------
# self.poblacion 10
# -----------75------------
# self.poblacion 10
# -----------76------------
# self.poblacion 10
# -----------77------------
# self.poblacion 10
# -----------78------------
# self.poblacion 10
# -----------79------------
# self.poblacion 10
# -----------80------------
# self.poblacion 10
# -----------81------------
# self.poblacion 10
# -----------82------------
# self.poblacion 10
# -----------83------------
# self.poblacion 10
# -----------84------------
# self.poblacion 10
# -----------85------------
# self.poblacion 10
# -----------86------------
# self.poblacion 10
# -----------87------------
# self.poblacion 10
# -----------88------------
# self.poblacion 10
# -----------89------------
# self.poblacion 10
# -----------90------------
# self.poblacion 10
# -----------91------------
# self.poblacion 10
# -----------92------------
# self.poblacion 10
# -----------93------------
# self.poblacion 10
# -----------94------------
# self.poblacion 10
# -----------95------------
# self.poblacion 10
# -----------96------------
# self.poblacion 10
# -----------97------------
# self.poblacion 10
# -----------98------------
# self.poblacion 10
# -----------99------------
# self.poblacion 10
# -----------100------------
# self.poblacion 10
# -----------101------------
# self.poblacion 10
# -----------102------------
# self.poblacion 10
# -----------103------------
# self.poblacion 10
# -----------104------------
# self.poblacion 10
# -----------105------------
# self.poblacion 10
# -----------106------------
# self.poblacion 10
# -----------107------------
# self.poblacion 10
# -----------108------------
# self.poblacion 10
# -----------109------------
# self.poblacion 10
# -----------110------------
# self.poblacion 10
# -----------111------------
# self.poblacion 10
# -----------112------------
# self.poblacion 10
# -----------113------------
# self.poblacion 10
# -----------114------------
# self.poblacion 10
# -----------115------------
# self.poblacion 10
# -----------116------------
# self.poblacion 10
# -----------117------------
# self.poblacion 10
# -----------118------------
# self.poblacion 10
# -----------119------------
# self.poblacion 10
# -----------120------------
# self.poblacion 10
# -----------121------------
# self.poblacion 10
# -----------122------------
# self.poblacion 10
# -----------123------------
# self.poblacion 10
# -----------124------------
# self.poblacion 10
# -----------125------------
# self.poblacion 10
# -----------126------------
# self.poblacion 10
# -----------127------------
# self.poblacion 10
# -----------128------------
# self.poblacion 10
# -----------129------------
# self.poblacion 10
# -----------130------------
# self.poblacion 10
# -----------131------------
# self.poblacion 10
# -----------132------------
# self.poblacion 10
# -----------133------------
# self.poblacion 10
# -----------134------------
# self.poblacion 10
# -----------135------------
# self.poblacion 10
# -----------136------------
# self.poblacion 10
# -----------137------------
# self.poblacion 10
# -----------138------------
# self.poblacion 10
# -----------139------------
# self.poblacion 10
# -----------140------------
# self.poblacion 10
# -----------141------------
# self.poblacion 10
# -----------142------------
# self.poblacion 10
# -----------143------------
# self.poblacion 10
# -----------144------------
# self.poblacion 10
# -----------145------------
# self.poblacion 10
# -----------146------------
# self.poblacion 10
# -----------147------------
# self.poblacion 10
# -----------148------------
# self.poblacion 10
# -----------149------------
# self.poblacion 10
# -----------150------------
# self.poblacion 10
# -----------151------------
# self.poblacion 10
# -----------152------------
# self.poblacion 10
# -----------153------------
# self.poblacion 10
# -----------154------------
# self.poblacion 10
# -----------155------------
# self.poblacion 10
# -----------156------------
# self.poblacion 10
# -----------157------------
# self.poblacion 10
# -----------158------------
# self.poblacion 10
# -----------159------------
# self.poblacion 10
# -----------160------------
# self.poblacion 10
# -----------161------------
# self.poblacion 10
# -----------162------------
# self.poblacion 10
# -----------163------------
# self.poblacion 10
# -----------164------------
# self.poblacion 10
# -----------165------------
# self.poblacion 10
# -----------166------------
# self.poblacion 10
# -----------167------------
# self.poblacion 10
# -----------168------------
# self.poblacion 10
# -----------169------------
# self.poblacion 10
# -----------170------------
# self.poblacion 10
# -----------171------------
# self.poblacion 10
# -----------172------------
# self.poblacion 10
# -----------173------------
# self.poblacion 10
# -----------174------------
# self.poblacion 10
# -----------175------------
# self.poblacion 10
# -----------176------------
# self.poblacion 10
# -----------177------------
# self.poblacion 10
# -----------178------------
# self.poblacion 10
# -----------179------------
# self.poblacion 10
# -----------180------------
# self.poblacion 10
# -----------181------------
# self.poblacion 10
# -----------182------------
# self.poblacion 10
# -----------183------------
# self.poblacion 10
# -----------184------------
# self.poblacion 10
# -----------185------------
# self.poblacion 10
# -----------186------------
# self.poblacion 10
# -----------187------------
# self.poblacion 10
# -----------188------------
# self.poblacion 10
# -----------189------------
# self.poblacion 10
# -----------190------------
# self.poblacion 10
# -----------191------------
# self.poblacion 10
# -----------192------------
# self.poblacion 10
# -----------193------------
# self.poblacion 10
# -----------194------------
# self.poblacion 10
# -----------195------------
# self.poblacion 10
# -----------196------------
# self.poblacion 10
# -----------197------------
# self.poblacion 10
# -----------198------------
# self.poblacion 10
# -----------199------------
# self.poblacion 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Francisco Mendiburu\Documents\algoritmos-geneticos\TP3\AlgoritmoGenetico\Main_TP3 copy.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Francisco%20Mendiburu/Documents/algoritmos-geneticos/TP3/AlgoritmoGenetico/Main_TP3%20copy.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> if i == ciclos-1:
#      <a href='vscode-notebook-cell:/c%3A/Users/Francisco%20Mendiburu/Documents/algoritmos-geneticos/TP3/AlgoritmoGenetico/Main_TP3%20copy.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a>     for cromosoma in poblacion:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Francisco%20Mendiburu/Documents/algoritmos-geneticos/TP3/AlgoritmoGenetico/Main_TP3%20copy.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a>         if cromosoma.objetivo > mejor_cromosoma[0]:
#      <a href='vscode-notebook-cell:/c%3A/Users/Francisco%20Mendiburu/Documents/algoritmos-geneticos/TP3/AlgoritmoGenetico/Main_TP3%20copy.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a>             mejor_cromosoma[0] = cromosoma.objetivo
#      <a href='vscode-notebook-cell:/c%3A/Users/Francisco%20Mendiburu/Documents/algoritmos-geneticos/TP3/AlgoritmoGenetico/Main_TP3%20copy.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a>             mejor_cromosoma[1] = cromosoma
#
# TypeError: '>' not supported between instances of 'NoneType' and 'int'
