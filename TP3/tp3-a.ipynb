# %% [markdown]
# ### Librerías

# %%
# instalar Pillow (pip install Pillow)
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

# %% [markdown]
# ### Carga de datos

# %%
# Ruta al archivo .xlsx
archivo_xlsx = 'TablaCapitales.xlsx'

# Cargar el archivo .xlsx en un DataFrame
df_base = pd.read_excel(archivo_xlsx, index_col=0)
df_base = df_base.iloc[:-2]
#df = df.fillna(0)
df_base
# Out:
#                           Cdad. de Bs. As.  Córdoba  Corrientes  Formosa
# Distancias en kilómetros
# Cdad. de Bs. As.                       NaN    646.0       792.0    933.0  \
# Córdoba                              646.0      NaN       677.0    824.0
# Corrientes                           792.0    677.0         NaN    157.0
# Formosa                              933.0    824.0       157.0      NaN
# La Plata                              53.0    698.0       830.0    968.0
# La Rioja                             986.0    340.0       814.0    927.0
# Mendoza                              985.0    466.0      1131.0   1269.0
# Neuquén                              989.0    907.0      1534.0   1690.0
# Paraná                               375.0    348.0       500.0    656.0
# Posadas                              834.0    919.0       291.0    263.0
# Rawson                              1127.0   1321.0      1845.0   1999.0
# Resistencia                          794.0    669.0        13.0    161.0
# Río Gallegos                        2082.0   2281.0      2819.0   2974.0
# S.F.d.V.d. Catamarca                 979.0    362.0       691.0    793.0
# S.M. de Tucumán                     1080.0    517.0       633.0    703.0
# S.S. de Jujuy                       1334.0    809.0       742.0    750.0
# Salta                               1282.0    745.0       719.0    741.0
# San Juan                            1005.0    412.0      1039.0   1169.0
# San Luis                             749.0    293.0       969.0   1117.0
# Santa Fe                             393.0    330.0       498.0    654.0
# Santa Rosa                           579.0    577.0      1136.0   1293.0
# Sgo. Del Estero                      939.0    401.0       535.0    629.0
# Ushuaia                             2373.0   2618.0      3131.0   3284.0
# Viedma                               799.0   1047.0      1527.0   1681.0
#
#                           La Plata  La Rioja  Mendoza  Neuquén  Paraná
# Distancias en kilómetros
# Cdad. de Bs. As.              53.0     986.0    985.0    989.0   375.0  \
# Córdoba                      698.0     340.0    466.0    907.0   348.0
# Corrientes                   830.0     814.0   1131.0   1534.0   500.0
# Formosa                      968.0     927.0   1269.0   1690.0   656.0
# La Plata                       NaN    1038.0   1029.0   1005.0   427.0
# La Rioja                    1038.0       NaN    427.0   1063.0   659.0
# Mendoza                     1029.0     427.0      NaN    676.0   790.0
# Neuquén                     1005.0    1063.0    676.0      NaN  1053.0
# Paraná                       427.0     659.0    790.0   1053.0     NaN
# Posadas                      857.0    1098.0   1384.0   1709.0   658.0
# Rawson                      1116.0    1548.0   1201.0    543.0  1345.0
# Resistencia                  833.0     802.0   1121.0   1529.0   498.0
# Río Gallegos                2064.0    2473.0   2081.0   1410.0  2320.0
# S.F.d.V.d. Catamarca        1030.0     149.0    569.0   1182.0   622.0
# S.M. de Tucumán             1132.0     330.0    756.0   1370.0   707.0
# S.S. de Jujuy               1385.0     600.0   1023.0   1658.0   959.0
# Salta                       1333.0     533.0    957.0   1591.0   906.0
# San Juan                    1053.0     283.0    152.0    824.0   757.0
# San Luis                     795.0     435.0    235.0    643.0   574.0
# Santa Fe                     444.0     640.0    775.0   1049.0    19.0
# Santa Rosa                   602.0     834.0    586.0    422.0   642.0
# Sgo. Del Estero              991.0     311.0    713.0   1286.0   566.0
# Ushuaia                     2350.0    2821.0   2435.0   1762.0  2635.0
# Viedma                       789.0    1311.0   1019.0    479.0  1030.0
#
#                           Posadas  ...  S.M. de Tucumán  S.S. de Jujuy
# Distancias en kilómetros           ...
# Cdad. de Bs. As.            834.0  ...           1080.0         1334.0  \
# Córdoba                     919.0  ...            517.0          809.0
# Corrientes                  291.0  ...            633.0          742.0
# Formosa                     263.0  ...            703.0          750.0
# La Plata                    857.0  ...           1132.0         1385.0
# La Rioja                   1098.0  ...            330.0          600.0
# Mendoza                    1384.0  ...            756.0         1023.0
# Neuquén                    1709.0  ...           1370.0         1658.0
# Paraná                      658.0  ...            707.0          959.0
# Posadas                       NaN  ...            924.0         1007.0
# Rawson                     1951.0  ...           1827.0         2120.0
# Resistencia                 305.0  ...            620.0          729.0
# Río Gallegos               2914.0  ...           2773.0         3063.0
# S.F.d.V.d. Catamarca        980.0  ...            189.0          477.0
# S.M. de Tucumán             924.0  ...              NaN          293.0
# S.S. de Jujuy              1007.0  ...            293.0            NaN
# Salta                       992.0  ...            228.0           67.0
# San Juan                   1306.0  ...            612.0          874.0
# San Luis                   1200.0  ...            727.0         1017.0
# Santa Fe                    664.0  ...            689.0          942.0
# Santa Rosa                 1293.0  ...           1088.0         1382.0
# Sgo. Del Estero             827.0  ...            141.0          414.0
# Ushuaia                    3207.0  ...           3116.0         3408.0
# Viedma                     1624.0  ...           1562.0         1855.0
#
#                            Salta  San Juan  San Luis  Santa Fe  Santa Rosa
# Distancias en kilómetros
# Cdad. de Bs. As.          1282.0    1005.0     749.0     393.0       579.0  \
# Córdoba                    745.0     412.0     293.0     330.0       577.0
# Corrientes                 719.0    1039.0     969.0     498.0      1136.0
# Formosa                    741.0    1169.0    1117.0     654.0      1293.0
# La Plata                  1333.0    1053.0     795.0     444.0       602.0
# La Rioja                   533.0     283.0     435.0     640.0       834.0
# Mendoza                    957.0     152.0     235.0     775.0       586.0
# Neuquén                   1591.0     824.0     643.0    1049.0       422.0
# Paraná                     906.0     757.0     574.0      19.0       642.0
# Posadas                    992.0    1306.0    1200.0     664.0      1293.0
# Rawson                    2054.0    1340.0    1113.0    1349.0       745.0
# Resistencia                706.0    1029.0     961.0     495.0      1132.0
# Río Gallegos              2997.0    2231.0    2046.0    2325.0      1712.0
# S.F.d.V.d. Catamarca       410.0     430.0     540.0     602.0       915.0
# S.M. de Tucumán            228.0     612.0     727.0     689.0      1088.0
# S.S. de Jujuy               67.0     874.0    1017.0     942.0      1382.0
# Salta                        NaN     808.0     950.0     889.0      1316.0
# San Juan                   808.0       NaN     284.0     740.0       686.0
# San Luis                   950.0     284.0       NaN     560.0       412.0
# Santa Fe                   889.0     740.0     560.0       NaN       641.0
# Santa Rosa                1316.0     686.0     412.0     641.0         NaN
# Sgo. Del Estero            353.0     583.0     643.0     547.0       977.0
# Ushuaia                   3341.0    2585.0    2392.0    2641.0      2044.0
# Viedma                    1790.0    1141.0     882.0    1035.0       477.0
#
#                           Sgo. Del Estero  Ushuaia  Viedma
# Distancias en kilómetros
# Cdad. de Bs. As.                    939.0   2373.0   799.0
# Córdoba                             401.0   2618.0  1047.0
# Corrientes                          535.0   3131.0  1527.0
# Formosa                             629.0   3284.0  1681.0
# La Plata                            991.0   2350.0   789.0
# La Rioja                            311.0   2821.0  1311.0
# Mendoza                             713.0   2435.0  1019.0
# Neuquén                            1286.0   1762.0   479.0
# Paraná                              566.0   2635.0  1030.0
# Posadas                             827.0   3207.0  1624.0
# Rawson                             1721.0   1300.0   327.0
# Resistencia                         523.0   3130.0  1526.0
# Río Gallegos                       2677.0    359.0  1294.0
# S.F.d.V.d. Catamarca                166.0   2931.0  1391.0
# S.M. de Tucumán                     141.0   3116.0  1562.0
# S.S. de Jujuy                       414.0   3408.0  1855.0
# Salta                               353.0   3341.0  1790.0
# San Juan                            583.0   2585.0  1141.0
# San Luis                            643.0   2392.0   882.0
# Santa Fe                            547.0   2641.0  1035.0
# Santa Rosa                          977.0   2044.0   477.0
# Sgo. Del Estero                       NaN   3016.0  1446.0
# Ushuaia                            3016.0      NaN  1605.0
# Viedma                             1446.0   1605.0     NaN
#
# [24 rows x 24 columns]

# %% [markdown]
# ### Funciones

# %% [markdown]
# #### Ciudad mas cercana

# %%
def heuristica(ciudad, df):
    if ciudad in df.index:
        # Utiliza 'idxmin' para encontrar la ciudad con la menor distancia a 'ciudad1'
        ciudad_menor_distancia = df.loc[ciudad].idxmin()
        distancia_minima = df.loc[ciudad, ciudad_menor_distancia]
        return ciudad_menor_distancia, distancia_minima
    else:
        print(f"{ciudad} no se encuentra en el DataFrame.")


heuristica("Santa Fe", df_base)
# Out:
# ('Paraná', 19.0)

# %% [markdown]
# #### Dibujar mapa

# %%
def dibujar_linea(imagen, punto_inicio, punto_fin, color, grosor=1):
    draw = ImageDraw.Draw(imagen)
    draw.line([punto_inicio, punto_fin], fill=color, width=grosor)

# %% [markdown]
# ### A

# %% [markdown]
# ##### Coordenadas

# %%
coordenadas = { "Santa Fe": (186,168), "Paraná": (214,181), "Córdoba": (146,185), "San Luis": (113,210), "Mendoza": (74,201), "San Juan": (77,178), "La Rioja": (102,145), "S.F.d.V.d. Catamarca": (115,122), "Sgo. Del Estero": (140,113), "S.M. de Tucumán": (124,99), "Salta": (122,61), "S.S. de Jujuy": (124,52),"Resistencia": (217,102), "Corrientes": (225,107), "Formosa": (234,85), "Posadas": (269,110), "Cdad. de Bs. As.": (229,238), "La Plata": (218,226), "Santa Rosa": (139,264), "Neuquén": (86,303), "Viedma": (158,334), "Rawson": (129,374), "Río Gallegos": (91,519), "Ushuaia": (108,568) }

# %% [markdown]
# ##### Main

# %%
imagen = Image.open("mapa.png")
df_ciudades = df_base
km_recorridos = 0
ciudad_inicial = "Santa Fe"
ciudad_i = ciudad_inicial
cantidad_de_columnas = df_base.shape[1]
recorridos = []
for i in range(1, cantidad_de_columnas):
    
    ciudad_proxima, distancia = heuristica(ciudad_i, df_ciudades)
    df_ciudades = df_ciudades.drop(ciudad_i, axis=1)
    km_recorridos += distancia
    data = [ciudad_i, ciudad_proxima, distancia, km_recorridos]
    recorridos.append(data)
    dibujar_linea(imagen, coordenadas[ciudad_i], coordenadas[ciudad_proxima], color="red", grosor=1)
    ciudad_i = ciudad_proxima
    

km_recorridos += df_base[ciudad_i][ciudad_inicial]
data = [ciudad_i, ciudad_inicial,df_base[ciudad_i][ciudad_inicial], km_recorridos]
recorridos.append(data)
dibujar_linea(imagen, coordenadas[ciudad_i], coordenadas[ciudad_inicial], color="red", grosor=1)

df_recorridos = pd.DataFrame(recorridos, columns=['Ciudad Inicial', 'Ciudad Final', 'Distancia (KM)', 'Total(KM)'])
imagen.save("imagen_con_lineas.png")
df_recorridos
# Out:
#           Ciudad Inicial          Ciudad Final  Distancia (KM)  Total(KM)
# 0               Santa Fe                Paraná            19.0       19.0
# 1                 Paraná               Córdoba           348.0      367.0
# 2                Córdoba              San Luis           293.0      660.0
# 3               San Luis               Mendoza           235.0      895.0
# 4                Mendoza              San Juan           152.0     1047.0
# 5               San Juan              La Rioja           283.0     1330.0
# 6               La Rioja  S.F.d.V.d. Catamarca           149.0     1479.0
# 7   S.F.d.V.d. Catamarca       Sgo. Del Estero           166.0     1645.0
# 8        Sgo. Del Estero       S.M. de Tucumán           141.0     1786.0
# 9        S.M. de Tucumán                 Salta           228.0     2014.0
# 10                 Salta         S.S. de Jujuy            67.0     2081.0
# 11         S.S. de Jujuy           Resistencia           729.0     2810.0
# 12           Resistencia            Corrientes            13.0     2823.0
# 13            Corrientes               Formosa           157.0     2980.0
# 14               Formosa               Posadas           263.0     3243.0
# 15               Posadas      Cdad. de Bs. As.           834.0     4077.0
# 16      Cdad. de Bs. As.              La Plata            53.0     4130.0
# 17              La Plata            Santa Rosa           602.0     4732.0
# 18            Santa Rosa               Neuquén           422.0     5154.0
# 19               Neuquén                Viedma           479.0     5633.0
# 20                Viedma                Rawson           327.0     5960.0
# 21                Rawson          Río Gallegos           975.0     6935.0
# 22          Río Gallegos               Ushuaia           359.0     7294.0
# 23               Ushuaia              Santa Fe          2641.0     9935.0

# %% [markdown]
# #### Coordenadas

# %%
# Mostrar la imagen
# imagen.show()

# %%
df_ciudades = df_base.copy()
cantidad_de_columnas = df_base.shape[1]
recorridos = []
lista_nombres = list(df_base.head(0))
ciudades_recorridos = []	
for i in range(0, len(lista_nombres)):
    df_ciudades = df_base.copy()
    km_recorridos = 0
    ciudad_inicial = lista_nombres[i]
    ciudad_i = ciudad_inicial
    for j in range(1, cantidad_de_columnas):
        ciudad_proxima, distancia = heuristica(ciudad_i, df_ciudades)
        df_ciudades = df_ciudades.drop(ciudad_i, axis=1)
        km_recorridos += distancia
        data = [ciudad_i, ciudad_proxima, distancia, km_recorridos]
        recorridos.append(data)
        ciudad_i = ciudad_proxima

    km_recorridos += df_base[ciudad_i][ciudad_inicial] 
    data = [ciudad_i, ciudad_inicial, df_base[ciudad_i][ciudad_inicial], km_recorridos]
    recorridos.append(data)
    ciudadInicial_kilometros = [lista_nombres[i], km_recorridos, recorridos]
    ciudades_recorridos.append(ciudadInicial_kilometros)
    recorridos = []
#ciudades_recorridos
lista_ordenada = sorted(ciudades_recorridos, key=lambda x: x[1])
#lista_ordenada[0]
df_recorridos = pd.DataFrame(lista_ordenada[0][2], columns=[
                             'Ciudad Inicial', 'Ciudad Final', 'Distancia (KM)', 'Total(KM)'])
df_recorridos
# Out:
#           Ciudad Inicial          Ciudad Final  Distancia (KM)  Total(KM)
# 0                Neuquén            Santa Rosa           422.0      422.0
# 1             Santa Rosa              San Luis           412.0      834.0
# 2               San Luis               Mendoza           235.0     1069.0
# 3                Mendoza              San Juan           152.0     1221.0
# 4               San Juan              La Rioja           283.0     1504.0
# 5               La Rioja  S.F.d.V.d. Catamarca           149.0     1653.0
# 6   S.F.d.V.d. Catamarca       Sgo. Del Estero           166.0     1819.0
# 7        Sgo. Del Estero       S.M. de Tucumán           141.0     1960.0
# 8        S.M. de Tucumán                 Salta           228.0     2188.0
# 9                  Salta         S.S. de Jujuy            67.0     2255.0
# 10         S.S. de Jujuy           Resistencia           729.0     2984.0
# 11           Resistencia            Corrientes            13.0     2997.0
# 12            Corrientes               Formosa           157.0     3154.0
# 13               Formosa               Posadas           263.0     3417.0
# 14               Posadas                Paraná           658.0     4075.0
# 15                Paraná              Santa Fe            19.0     4094.0
# 16              Santa Fe               Córdoba           330.0     4424.0
# 17               Córdoba      Cdad. de Bs. As.           646.0     5070.0
# 18      Cdad. de Bs. As.              La Plata            53.0     5123.0
# 19              La Plata                Viedma           789.0     5912.0
# 20                Viedma                Rawson           327.0     6239.0
# 21                Rawson          Río Gallegos           975.0     7214.0
# 22          Río Gallegos               Ushuaia           359.0     7573.0
# 23               Ushuaia               Neuquén          1762.0     9335.0
